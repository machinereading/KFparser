# %%
import json
with open('./tmp/ds_result.json') as f:
    d = json.load(f)

# %%
print(d[0]['dbpedia'])
# Out:
# [['유고슬라비아_공산주의자_동맹', 'headquarter', '유고슬라비아'], ['K리그_챌린지_2015', 'team', '수원_FC'], ['묘코_시', 'isPartOf', '니가타_현'], ['조선_인조', 'dynasty', '조선'], ['이치노세키_시', 'isPartOf', '이와테_현'], ['삼감의_난', 'commander', '무경_(상나라)'], ['클루브_볼리바르', 'ground', '볼리비아'], ['장탕', 'position', '사공_(관직)'], ['뉴질랜드', 'leader', '엘리자베스_2세'], ['장충체육관', 'operator', '서울특별시'], ['박상민_(배우)', 'education', '서울예술대학교'], ['애플_페이', 'computingPlatform', '아이패드_미니_3'], ['해리_S._트루먼', 'region', '미주리_주'], ['카이위안_시_(톄링_시)', 'isPartOf', '톄링_시'], ['1974년_2월_영국_총선', 'country', '영국'], ['국악한마당', 'title', 'KBS_1TV'], ['사가미_철도', 'location', '가나가와_현'], ['세이부_유라쿠초_선', 'routeEnd', '도쿄_도'], ['이에로클리스_스톨티디스', 'team', '그리스_축구_국가대표팀'], ['선흥상운', 'location', '서울특별시'], ['쿠르트_괴델', 'knownFor', '수학'], ['조선_경종', 'deathPlace', '한성부'], ['마르셀루_비에이라', 'birthPlace', '브라질'], ['밝은미래_(아이슬란드)', 'ideology', '자유주의'], ['알프레드_노스_화이트헤드', 'influenced', '버트런드_러셀'], ['마리_드_메디시스', 'child', '루이_13세'], ['렙토케라톱스과', 'order', '공룡'], ['게센누마_선', 'owner', '동일본_여객철도'], ['곽거병', 'position'
# ...
