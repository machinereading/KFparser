# %%
# input: CoNLL2009-based list (output of preprocessor.py)

from koreanframenet import kfn
import preprocessor
import re

# %%
def target_identification_surfaceform(sent_list):
    result = []
    frame = 'None'
    for i in sent_list:
        print(i[0], i[2], i[3])
        lu1, lu2 = [],[]
        #print(i)
        lus =[]
        lemma = i[2].split('+')[0]
        #lu1 = kfn.lus_by_lemma(lemma)
        
        surfaceform = i[1]
        spc = [',','.','!','?']
        if len(surfaceform) > 1:
            if surfaceform[-1] in spc:
                surfaceform = re.sub('[,.?!]', '', surfaceform)
        lu2 = kfn.lus_by_surfaceform(surfaceform)
        lus = lu1+lu2
        lus = list(set(lus))
        print(lus)
        
        pos = i[4].split('+')[0]
        if pos.startswith('N'):
            pos = 'n'
        elif pos == 'VV':
            pos = 'v'
        elif pos == 'VA':
            pos = 'a'
        else:
            pass
        lu_candi = []
        if len(lus) > 0:
            for lc in lus:
                lu_pos = lc.split('.')[1]
                print('pos', pos, lu_pos)
                if pos == lu_pos:
                    lu_candi_list = lc.split('.')[:-1]
                    lu_candi = '.'.join(lu_candi_list)
                    #print(lu_candi)
                    if surfaceform[0] == lu_candi[0]:
                        lu_candis.append(lu_candi)
        lu_candis = list(set(lu_candis))
        if len(lu_candis) > 0:
            lu_dict = {}
            lu_dict['token_id'] = i[0]
            lu_dict['lu'] = lu_candis
            lu_dict['lu_with_frame'] = lus
            result.append(lu_dict)
    return result

# %%
def dummy():
    st = '선언서를'
    d = kfn.lus_by_surfaceform(st)
    print(d)
dummy()
# Out:
# ['선언서.n.Statement']

# %%
def test():
    data, _, _ = preprocessor.load_data()
    sent_list = data[0]
    #for i in sent_list:
    #    print(i[0], i[2])
    #print('')
    targets = target_identification_surfaceform(sent_list)
    print(targets)
test()
# Out:
# ### loading data now...
# # training_data
#  - number of full-sentences: 14811
#  - number of sentences: 33311
#
# # test_data
#  - number of full-sentences: 1863
#  - number of sentences: 2793
#
# # training_fe (for FE identification)
#  - number of full-sentences: 4248
#  - number of sentences: 14462
#
# 0 이란/NNG+은/JX 이란은
# []
# 1 화학/NNG 화학
# ['화학.n.Substance', '화학.n.Weapon']
# pos n n
# pos n n
# 2 시설/NNG+과/JC 시설과
# ['시설.n.Locale_by_use']
# pos n n
# 3 과거/NNG 과거
# ['과거.n.Relative_time']
# pos n n
# 4 화학무기/NNG 화학무기
# ['무기.n.Weapon', '무기.n.Hostile_encounter', '화학.n.Substance']
# pos n n
# pos n n
# pos n n
# 5 비축/NNG+에/JKB 비축에
# ['비축.n.Store']
# pos n n
# 6 관하/VV+ㄴ/ETM 관한
# ['관하다.v.Topic']
# pos v v
# 7 선언서/NNG+를/JKO 선언서를
# ['선언서.n.Statement']
# pos n n
# 8 제출하/VV+었/EP+는데/EC+,/SP 제출하였는데,
# []
# 9 이란/NNG+은/JX 이란은
# []
# 10 화학무기/NNG 화학무기
# ['무기.n.Weapon', '무기.n.Hostile_encounter', '화학.n.Substance']
# pos n n
# pos n n
# pos n n
# 11 금지기구/NNG 금지기구
# []
# 12 조사관들/NNG+이/JKS 조사관들이
# ['조사관들.n.Inspecting', '조사관들.n.Scrutiny']
# pos n n
# pos n n
# 13 있/VA+는/ETM 있는
# ['있다.a.Possession', '있다.a.Being_located', '있다.a.Existence', '있다.a.Containing']
# pos a a
# pos a a
# pos a a
# pos a a
# 14 곳/NNG+에서/JKB 곳에서
# ['곳.n.Locative_relation', '곳.n.Locale']
# pos n n
# pos n n
# 15 화학무기/NNG 화학무기
# ['무기.n.Weapon', '무기.n.Hostile_encounter', '화학.n.Substance']
# pos n n
# pos n n
# pos n n
# 16 생산/NNG 생산
# ['생산.n.Intentionally_create', '생산.n.Manufacturing']
# pos n n
# pos n n
# 17 장비/NNG+를/JKO 장비를
# ['장비.n.Supply', '장비.n.Gizmo']
# pos n n
# pos n n
# 18 파괴하/VV+었/EP+고/EC+,/SP 파괴하였고,
# ['파괴하다.v.Destroying']
# pos v v
# 19 화학/NNG 화학
# ['화학.n.Substance', '화학.n.Weapon']
# pos n n
# pos n n
# 20 산업/NNG 산업
# ['산업.n.Manufacturing', '산업.n.Fields']
# pos n n
# pos n n
# 21 시설들/NNG+에/JKB 시설들에
# ['시설.n.Locale_by_use']
# pos n n
# 22 대하/VV+어/EC 대해
# ['대하다.v.Topic', '대하다.v.Quantity']
# pos v v
# pos v v
# 23 화학무기/NNG 화학무기
# ['무기.n.Weapon', '무기.n.Hostile_encounter', '화학.n.Substance']
# pos n n
# pos n n
# pos n n
# 24 금지기구/NNG+의/JKG 금지기구의
# []
# 25 조사/NNG+를/JKO 조사를
# ['조사.n.Inspecting', '조사.n.Scrutiny']
# pos n n
# pos n n
# 26 수/MM 수
# ['수.n.Quantity', '수.n.Likelihood', '수.n.Capability', '수.n.Desirable_event']
# pos MM n
# pos MM n
# pos MM n
# pos MM n
# 27 차례/NNG 차례
# []
# 28 받/VV+었/EP+다/EF+./SF 받았다.
# ['축하받다.v.Communication_response', '축하받다.v.Getting', '축하받다.v.Undergoing', '축하받다.v.Receiving']
# pos v v
# pos v v
# pos v v
# pos v v
# [{'token_id': '1', 'lu': ['화학.n']}, {'token_id': '2', 'lu': ['시설.n']}, {'token_id': '3', 'lu': ['과거.n']}, {'token_id': '4', 'lu': ['화학.n']}, {'token_id': '5', 'lu': ['비축.n']}, {'token_id': '6', 'lu': ['관하다.v']}, {'token_id': '7', 'lu': ['선언서.n']}, {'token_id': '10', 'lu': ['화학.n']}, {'token_id': '12', 'lu': ['조사관들.n']}, {'token_id': '13', 'lu': ['있다.a']}, {'token_id': '14', 'lu': ['곳.n']}, {'token_id': '15', 'lu': ['화학.n']}, {'token_id': '16', 'lu': ['생산.n']}, {'token_id': '17', 'lu': ['장비.n']}, {'token_id': '18', 'lu': ['파괴하다.v']}, {'token_id': '19', 'lu': ['화학.n']}, {'token_id': '20', 'lu': ['산업.n']}, {'token_id': '21', 'lu': ['시설.n']}, {'token_id': '22', 'lu': ['대하다.v']}, {'token_id': '23', 'lu': ['화학.n']}, {'token_id': '25', 'lu': ['조사.n']}]
